# %%
from scipy.stats.distributions import bernoulli

dt = 0.0005 #time step
T = 0.500  #total simulation time
nsteps = int(T / dt)
N = 1      #number of input neurons

#generate a binary spike train as input
Xrate = 0.001
print 'Spike Rate: %0.1f Hz' % (Xrate / dt)
X = bernoulli.rvs(0.5, size=[nsteps, N])

#generate the input weight matrix
W = np.zeros(N)
W[0] = 0.75

#visualize synaptic transfer function
etau = 0.010 #10ms decay constant for synaptic input
synapse_func = lambda t: np.exp(-t / etau)
t = np.arange(0.0, 0.100, dt)
plt.plot(t, synapse_func(t), 'r-')
plt.title('Synaptic Decay Function')

#membrane potential function params
ur = -0.070 #reset potential
u0 = -0.065 #resting potential
du = 0.002

#simulate
u = np.zeros(nsteps)
for k in range(nsteps):
    for n in range(N):
        #tX = 
        #u[k] = ur + 
        pass
# Out:
# Spike Rate: 2.0 Hz
